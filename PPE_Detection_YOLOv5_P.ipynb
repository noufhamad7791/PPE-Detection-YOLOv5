# %% [markdown]
# # PPE Detection using YOLOv5
#
# ## Project Overview
#
# This project uses YOLOv5 for Personal Protective Equipment (PPE) object detection.
#
# The model detects four classes:
# - Boots
# - Helmet
# - Person
# - Vest

# %% [markdown]
# ## 1.  Dataset
#
# The project uses a PPE object-detection dataset from Roboflow.
#
# The model was evaluated on four PPE-related classes:
# - Boots
# - Helmet
# - Person
# - Vest
#
# Dataset source: [Roboflow – PPE Dataset for Workplace Safety](https://universe.roboflow.com/n-4cjfd/ppe-dataset-for-workplace-safety-2rrlg/dataset/1)

# %%
# !unzip "/content/PPE Dataset for Workplace Safety.v1i.yolov5pytorch .zip" -d NEW

# %% [markdown]
# ## 2. YOLOv5 Setup
#
# YOLOv5 was cloned from its GitHub repository and its required dependencies were installed.

# %%
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# !pip install -r requirements.txt

# %% [markdown]
# ## 3. Model Training
#
# The original training configuration used:
# - Pretrained weights: `yolov5s.pt`
# - Image size: `640`
# - Batch size: `16`
# - Epochs: `30`
# - Dataset configuration: `data.yaml`

# %%
# !python /content/yolov5/train.py \
--img 640 \
--batch 16 \
--epochs 30 \
--data /content/NEW/data.yaml \
--weights yolov5s.pt \
--project /content/yolov5_runs \
--name PPE_training \
--exist-ok

# %% [markdown]
# ## 4. Model Evaluation
#
# The trained model was evaluated using object-detection performance metrics.
#
# The reported evaluation results are stored in `M.txt`.

# %% [markdown]
# ## 5. Reported Results
#
# The repository includes reported evaluation results in `M.txt`.
#
# | Metric | Reported value |
# |---|---:|
# | Precision | 0.966 |
# | Recall | 0.947 |
# | mAP@50 | 0.972 |
# | mAP@50-95 | 0.770 |
# | FPS | 75.64 |
